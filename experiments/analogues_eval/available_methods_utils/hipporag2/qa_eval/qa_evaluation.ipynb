# %%
# Зафиксировать гиперпараметры

# %%
# Зафиксировать конфигурацию основного класса

# %%
# Инициализировать основной класс

# %%
# Построить граф

# %%
# Сохранить граф

# %%
# Запустить QA

# %%
# Оценить качество сгенерированных ответов
