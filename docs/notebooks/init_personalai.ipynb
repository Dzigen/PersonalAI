# %%
import sys
import json
# TO CHANGE
BASEDIR = "../.."
sys.path.insert(0, BASEDIR)

# %%
from pprint import pprint

# %%
from src import PersonalAI, PersonalAIConfig
from src.kg_model import KnowledgeGraphModelConfig
from src.db_drivers.vector_driver.embedders import EmbedderModelConfig

from src.pipelines.qa import QAPipelineConfig
from src.pipelines.qa.kg_reasoning import KnowledgeGraphReasonerConfig
from src.pipelines.qa.query_preprocessing import QueryPreprocessorConfig
from src.pipelines.qa.kg_reasoning.weak_reasoner import WeakKGReasonerConfig
from src.pipelines.qa.kg_reasoning.medium_reasoner import MediumKGReasonerConfig

from src.pipelines.qa.kg_reasoning.weak_reasoner.knowledge_retriever import KnowledgeRetrieverConfig
from src.pipelines.qa.kg_reasoning.weak_reasoner.knowledge_retriever.traversal_methods import WaterCirclesSearchConfig

# %%
kg_config = KnowledgeGraphModelConfig(
    nodestree_config=None # Модель дерева вершин строиться не будет
)
EMBEDDER_MODEL_PATH = '../../models/intfloat/multilingual-e5-small' # PATH TO APPROPRIATE EMBEDDER-MODEL
kg_config.embedders_configs['m-e5-small'] = EmbedderModelConfig(model_name_or_path=EMBEDDER_MODEL_PATH)

# %%
pai_config = PersonalAIConfig(
    lang='ru',
    kg_model_config=kg_config,
    qa_pipeline_config=QAPipelineConfig(
        preprocessor_config=QueryPreprocessorConfig(
            denoising_config=None, # None | by default
            enhancing_config=None, # None | by default
            decomposition_config=None
        ),
        reasoner_config=KnowledgeGraphReasonerConfig(
            reasoner_name='weak', # 'weak' | 'medium'
            reasoner_config=WeakKGReasonerConfig(
                knowledge_retriever_config=KnowledgeRetrieverConfig(
                    retriever_method='watercircles',
                    retriever_config=WaterCirclesSearchConfig()
                )
            )  # WeakKGReasonerConfig() |  MediumKGReasonerConfig()
        )
    )
)

# %%
pprint(pai_config)
# Out:
# PersonalAIConfig(lang='ru',
#                  log=<src.utils.logger.Logger object at 0x7fbf24a88760>,
#                  verbose=False,
#                  kg_model_config=KnowledgeGraphModelConfig(log=<src.utils.logger.Logger object at 0x7fbf24d21750>,
#                                                            verbose=False,
#                                                            graph_struct_config=GraphModelConfig(log=<src.utils.logger.Logger object at 0x7fc062658e50>,
#                                                                                                 verbose=False,
#                                                                                                 driver_config=GraphDriverConfig(db_vendor='kuzu',
#                                                                                                                                 db_config=GraphDBConnectionConfig(db_info={'db': 'DefaultDB',
#                                                                                                                                                                            'table': 'KuzuGraph'},
#                                                                                                                                                                   params={'buffer_pool_size': 1073741824,
#                                                                                                                                                                           'path': './personalai_tmp/memory_parts/graph_model/kuzu',
#                                                                                                                                                                           'table_type_map': {'nodes': {'forward': {'episodic': 'episodic',
#                                                                                                                                                                                                                    'hyper': 'hyper',
#                                                                                                                                                                                                                    'object': 'object',
#                                                                                                                                                                                                                    'time': 'time'}},
#                                                                                                                                                                                              'relations': {'forward': {'episodic': 'episodic_rel',
#                                                                                                                                                                                                                        'hyper': 'hyper_rel',
#                                                                                                                                                                                                                        'simple': 'simple',
#                                                                                                                                                                                                                        'time': 'time_rel'}}}},
#                                                                                                                                                                   need_to_clear=False,
#                                                                                                                                                                   create_index=False,
#                                                                                                                                                                   host=None,
#                                                                                                                                                                   port=None))),
#                                                            graph_embeddings_config=EmbeddingsModelConfig(log=<src.utils.logger.Logger object at 0x7fbf24d218d0>,
#                                                                                                          verbose=False,
#                                                                                                          nodesdb_driver_configs_mapping={'nodes_dense': VectorDriverConfig(db_vendor='chroma',
#                                                                                                                                                                            vector_category='dense',
#                                                                                                                                                                            db_config=VectorDBConnectionConfig(db_info={'db': 'default_db',
#                                                                                                                                                                                                                        'table': 'dense_nodes'},
#                                                                                                                                                                                                               params={'hnsw:M': 4096,
#                                                                                                                                                                                                                       'hnsw:space': 'ip'},
#                                                                                                                                                                                                               need_to_clear=False,
#                                                                                                                                                                                                               create_index=False,
#                                                                                                                                                                                                               conn={'path': './personalai_tmp/memory_parts/embeddings_model/vectorized_nodes/chroma'})),
#                                                                                                                                          'nodes_sparse_bm25': VectorDriverConfig(db_vendor='inmemory',
#                                                                                                                                                                                  vector_category='sparse_bm25',
#                                                                                                                                                                                  db_config=VectorDBConnectionConfig(db_info={'db': 'default_db',
#                                                                                                                                                                                                                              'table': 'sparsebm25_nodes'},
#                                                                                                                                                                                                                     params={'load_dump_dir': './personalai_tmp/memory_parts/embeddings_model/vectorized_nodes/inmemory_bm25',
#                                                                                                                                                                                                                             'load_dump_name': None,
#                                                                                                                                                                                                                             'load_from_disk': True,
#                                                                                                                                                                                                                             'save_dump_dir': './personalai_tmp/memory_parts/embeddings_model/vectorized_nodes/inmemory_bm25',
#                                                                                                                                                                                                                             'save_on_disk': True,
#                                                                                                                                                                                                                             'store_dump_name': 'inmemory_bm25'},
#                                                                                                                                                                                                                     need_to_clear=False,
#                                                                                                                                                                                                                     create_index=False,
#                                                                                                                                                                                                                     conn={}))},
#                                                                                                          tripletsdb_driver_configs_mapping={'triplets_dense': VectorDriverConfig(db_vendor='chroma',
#                                                                                                                                                                                  vector_category='dense',
#                                                                                                                                                                                  db_config=VectorDBConnectionConfig(db_info={'db': 'default_db',
#                                                                                                                                                                                                                              'table': 'vectorized_triplets'},
#                                                                                                                                                                                                                     params={'hnsw:M': 4096,
#                                                                                                                                                                                                                             'hnsw:space': 'ip'},
#                                                                                                                                                                                                                     need_to_clear=False,
#                                                                                                                                                                                                                     create_index=False,
#                                                                                                                                                                                                                     conn={'path': './personalai_tmp/memory_parts/embeddings_model/vectorized_triplets/chroma'})),
#                                                                                                                                             'triplets_sparse_bm25': VectorDriverConfig(db_vendor='inmemory',
#                                                                                                                                                                                        vector_category='sparse_bm25',
#                                                                                                                                                                                        db_config=VectorDBConnectionConfig(db_info={'db': 'default_db',
#                                                                                                                                                                                                                                    'table': 'sparsebm25_triplets'},
#                                                                                                                                                                                                                           params={'load_dump_dir': './personalai_tmp/memory_parts/embeddings_model/vectorized_triplets/inmemory_bm25',
#                                                                                                                                                                                                                                   'load_dump_name': None,
#                                                                                                                                                                                                                                   'load_from_disk': True,
#                                                                                                                                                                                                                                   'save_dump_dir': './personalai_tmp/memory_parts/embeddings_model/vectorized_triplets/inmemory_bm25',
#                                                                                                                                                                                                                                   'save_on_disk': True,
#                                                                                                                                                                                                                                   'store_dump_name': 'inmemory_bm25'},
#                                                                                                                                                                                                                           need_to_clear=False,
#                                                                                                                                                                                                                           create_index=False,
#                                                                                                                                                                                                                           conn={}))}),
#                                                            nodestree_config=None,
#                                                            embedders_configs={'m-e5-small': EmbedderModelConfig(model_name_or_path='../../models/intfloat/multilingual-e5-small',
#                                                                                                                 prompts={'passage': 'passage: ',
#                                                                                                                          'query': 'query: '},
#                                                                                                                 query_prompt_name='query',
#                                                                                                                 passage_prompt_name='passage',
#                                                                                                                 device='cuda',
#                                                                                                                 normalize_embeddings=True)},
#                                                            embedders_map=KGEmbeddersMapping(embeddings_model={'nodes_dense': 'm-e5-small',
#                                                                                                               'triplets_dense': 'm-e5-small'},
#                                                                                             nodestree_model={'leaf_dense_nodes': 'm-e5-small',
#                                                                                                              'summ_dense_nodes': 'm-e5-small'}),
#                                                            agents_configs={'llama3.1:8b': AgentDriverConfig(name='ollama',
#                                                                                                             agent_config=AgentConnectorConfig(gen_strategy={'num_predict': 2048,
#                                                                                                                                                             'seed': 42,
#                                                                                                                                                             'temperature': 0.0,
#                                                                                                                                                             'top_k': 1},
#                                                                                                                                               credentials={'host': 'localhost',
#                                                                                                                                                            'model': 'llama3.1:8b',
#                                                                                                                                                            'port': 11437},
#                                                                                                                                               ext_params={'keep_alive': -1,
#                                                                                                                                                           'timeout': 560,
#                                                                                                                                                           'trials': 5}))},
#                                                            agents_map=AgentsMapping(qa_pipeline='llama3.1:8b',
#                                                                                     mem_pipeline='llama3.1:8b',
#                                                                                     kg_nodestree_model='llama3.1:8b')),
#                  qa_pipeline_config=QAPipelineConfig(lang='auto',
#                                                      log=<src.utils.logger.Logger object at 0x7fbf24a86e90>,
#                                                      verbose=False,
#                                                      preprocessor_config=QueryPreprocessorConfig(lang='auto',
#                                                                                                  log=<src.utils.logger.Logger object at 0x7fbf24a7ffa0>,
#                                                                                                  verbose=False,
#                                                                                                  denoising_config=None,
#                                                                                                  enhancing_config=None,
#                                                                                                  decomposition_config=None,
#                                                                                                  cache_table_name='query_preprocessing_main_stage_cache'),
#                                                      reasoner_config=KnowledgeGraphReasonerConfig(lang='auto',
#                                                                                                   log=<src.utils.logger.Logger object at 0x7fbf24a876a0>,
#                                                                                                   verbose=False,
#                                                                                                   reasoner_name='weak',
#                                                                                                   reasoner_config=WeakKGReasonerConfig(lang='auto',
#                                                                                                                                        log=<src.utils.logger.Logger object at 0x7fbf24a7f790>,
#                                                                                                                                        verbose=False,
#                                                                                                                                        query_parser_config=QueryLLMParserConfig(lang='auto',
#                                                                                                                                                                                 log=<src.utils.logger.Logger object at 0x7fbf24a7d780>,
#                                                                                                                                                                                 verbose=False,
#                                                                                                                                                                                 agent_gen_stategy=None,
#                                                                                                                                                                                 agent_tasks_config=QueryLLMParserAgentTasksConfig(task_to_selector_mapping={'kw_extraction': <class 'src.pipelines.qa.kg_reasoning.weak_reasoner.query_parser.agent_tasks.kw_extraction.selector.AgentKWETaskConfigSelector'>},
#                                                                                                                                                                                                                                   kw_extraction='v2'),
#                                                                                                                                                                                 max_entities=20,
#                                                                                                                                                                                 cache_table_name='qa_queryparser_stage_cache'),
#                                                                                                                                        knowledge_comparator_config=KnowledgeComparatorConfig(log=<src.utils.logger.Logger object at 0x7fbf24a7d7e0>,
#                                                                                                                                                                                              verbose=False,
#                                                                                                                                                                                              reranker_driver_config=RerankerDriverConfig(name='ensemble_fusion',
#                                                                                                                                                                                                                                          strategy_config=EnsembleFusionRerankerConfig(vdb_names=['nodes_dense',
#                                                                                                                                                                                                                                                                                                  'nodes_sparse_bm25'],
#                                                                                                                                                                                                                                                                                       retriever_configs=None,
#                                                                                                                                                                                                                                                                                       weights=[0.2,
#                                                                                                                                                                                                                                                                                                0.8],
#                                                                                                                                                                                                                                                                                       c=60)),
#                                                                                                                                                                                              max_k=1,
#                                                                                                                                                                                              k_compare=5,
#                                                                                                                                                                                              cache_table_name='qa_kcomparator_stage_cache'),
#                                                                                                                                        knowledge_retriever_config=KnowledgeRetrieverConfig(log=<src.utils.logger.Logger object at 0x7fbf24a7f850>,
#                                                                                                                                                                                            verbose=False,
#                                                                                                                                                                                            retriever_method='watercircles',
#                                                                                                                                                                                            retriever_config=WaterCirclesSearchConfig(accepted_node_types=[<NodeType.object: 'object'>,
#                                                                                                                                                                                                                                                           <NodeType.hyper: 'hyper'>,
#                                                                                                                                                                                                                                                           <NodeType.episodic: 'episodic'>,
#                                                                                                                                                                                                                                                           <NodeType.time: 'time'>],
#                                                                                                                                                                                                                                      strict_filter=True,
#                                                                                                                                                                                                                                      hyper_num=25,
#                                                                                                                                                                                                                                      episodic_num=15,
#                                                                                                                                                                                                                                      chain_triplets_num=25,
#                                                                                                                                                                                                                                      other_triplets_num=6,
#                                                                                                                                                                                                                                      do_text_pruning=False,
#                                                                                                                                                                                                                                      cache_table_name='qa_watercircles_t_retriever_cache'),
#                                                                                                                                                                                            filter_method='naive',
#                                                                                                                                                                                            filter_config=TripletsFilterConfig(reranker_driver_config=RerankerDriverConfig(name='ensemble_fusion',
#                                                                                                                                                                                                                                                                           strategy_config=EnsembleFusionRerankerConfig(vdb_names=['triplets_dense',
#                                                                                                                                                                                                                                                                                                                                   'triplets_sparse_bm25'],
#                                                                                                                                                                                                                                                                                                                        retriever_configs=[RetrieverConfig(fetch_n=50,
#                                                                                                                                                                                                                                                                                                                                                           threshold=0.5),
#                                                                                                                                                                                                                                                                                                                                           RetrieverConfig(fetch_n=50,
#                                                                                                                                                                                                                                                                                                                                                           threshold=0.5)],
#                                                                                                                                                                                                                                                                                                                        weights=[0.7,
#                                                                                                                                                                                                                                                                                                                                 0.3],
#                                                                                                                                                                                                                                                                                                                        c=60)),
#                                                                                                                                                                                                                               accepted_triplets_types=[<RelationType.hyper: 'hyper'>,
#                                                                                                                                                                                                                                                        <RelationType.simple: 'simple'>],
#                                                                                                                                                                                                                               max_k=50,
#                                                                                                                                                                                                                               cache_table_name='qa_naive_t_filter_cache'),
#                                                                                                                                                                                            cache_table_name='qa_kretriever_stage_cache'),
#                                                                                                                                        answer_generator_config=QALLMGeneratorConfig(lang='auto',
#                                                                                                                                                                                     log=<src.utils.logger.Logger object at 0x7fbf24a86d40>,
#                                                                                                                                                                                     verbose=False,
#                                                                                                                                                                                     agent_gen_stategy=None,
#                                                                                                                                                                                     agent_tasks_config=QALLMGeneratorAgentTasksConfig(task_to_selector_mapping={'ag': <class 'src.pipelines.qa.kg_reasoning.weak_reasoner.answer_generator.agent_tasks.ag.selector.AgentSimpleAGTaskConfigSelector'>},
#                                                                                                                                                                                                                                       ag='v3'),
#                                                                                                                                                                                     relation_type=[<RelationType.hyper: 'hyper'>,
#                                                                                                                                                                                                    <RelationType.simple: 'simple'>],
#                                                                                                                                                                                     cache_table_name='qa_agenerator_stage_cache'),
#                                                                                                                                        cache_table_name='qa_weakreasoner_cache'),
#                                                                                                   cache_table_name='kg_reasoning_main_stage_cache'),
#                                                      aggregator_config=AnswersAggregatorConfig(lang='auto',
#                                                                                                log=<src.utils.logger.Logger object at 0x7fbf24a88730>,
#                                                                                                verbose=False,
#                                                                                                agent_gen_stategy=None,
#                                                                                                agent_tasks_config=AnswersAggregatorAgentTasksConfig(task_to_selector_mapping={'suba_summarisation': <class 'src.pipelines.qa.answers_aggregation.agent_tasks.answers_summarisation.selector.AgentSubASummTaskConfigSelector'>},
#                                                                                                                                                     suba_summarisation='v1'),
#                                                                                                cache_table_name='answers_aggregation_main_stage_cache'),
#                                                      cache_table_name='qa_pipeline_cache'),
#                  mem_pipeline_config=MemPipelineConfig(lang='auto',
#                                                        log=<src.utils.logger.Logger object at 0x7fbf24a88610>,
#                                                        verbose=False,
#                                                        extractor_config=LLMExtractorConfig(lang='auto',
#                                                                                            log=<src.utils.logger.Logger object at 0x7fbf24a88520>,
#                                                                                            verbose=False,
#                                                                                            agent_gen_stategy=None,
#                                                                                            agent_tasks_config=MemExtractorAgentTasksConfig(task_to_selector_mapping={'thesises_extraction': <class 'src.pipelines.memorize.extractor.agent_tasks.thesis_extraction.selector.AgentThesisExtrTaskConfigSelector'>,
#                                                                                                                                                                      'triplets_extraction': <class 'src.pipelines.memorize.extractor.agent_tasks.triplet_extraction.selector.AgentTripletExtrTaskConfigSelector'>},
#                                                                                                                                            triplets_extraction='v2',
#                                                                                                                                            thesises_extraction='v2'),
#                                                                                            need_simple=True,
#                                                                                            need_thesises=True,
#                                                                                            need_episodic=True),
#                                                        updator_config=LLMUpdatorConfig(lang='auto',
#                                                                                        log=<src.utils.logger.Logger object at 0x7fbf24a88940>,
#                                                                                        verbose=False,
#                                                                                        agent_gen_stategy=None,
#                                                                                        agent_tasks_config=MemUpdatorAgentTasksConfig(task_to_selector_mapping={'replace_simple': <class 'src.pipelines.memorize.updator.agent_tasks.replace_simple_triplets.selector.AgentReplSimpleTripletTaskConfigSelector'>,
#                                                                                                                                                                'replace_thesis': <class 'src.pipelines.memorize.updator.agent_tasks.replace_thesis_triplets.selector.AgentReplThesisTripletTaskConfigSelector'>},
#                                                                                                                                      replace_simple='v1',
#                                                                                                                                      replace_thesis='v1'),
#                                                                                        delete_obsolete_info=False)))

# %%
personalai = PersonalAI(pai_config)
# Out:
# No sentence-transformers model found with name ../../models/intfloat/multilingual-e5-small. Creating a new one with mean pooling.
# warning: graph-dump './personalai_tmp/memory_parts/graph_model/kuzu/DefaultDB/KuzuGraph' doesnt exists. creating empty graph-store

# %%
personalai.mem_pipeline.clear_kv_caches()
personalai.qa_pipeline.clear_kv_caches(
    #clear_traversal_cache=True,
    #clear_retrieval_cache=True
)

# %%
personalai.mem_pipeline.clear_agent_tgen_stat()
personalai.qa_pipeline.clear_agent_tgen_stat()

# %%
print("mem kv_cache info:")
print(json.dumps(personalai.mem_pipeline.get_cache_stat(), indent=5))
print("mem agent tgen info:")
print(json.dumps(personalai.mem_pipeline.get_agent_tgen_stat(), indent=5))
# Out:
# mem kv_cache info:
# {
#      "MemPipeline": null,
#      "extractor": {
#           "LLMExtractor": null,
#           "triplets_extraction_solver": 0,
#           "thesises_extraction_solver": 0
#      },
#      "updator": {
#           "LLMUpdator": null,
#           "replace_simple_solver": 0,
#           "replace_hyper_solver": 0
#      }
# }
# mem agent tgen info:
# {
#      "extractor": {
#           "triplets_extraction_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           },
#           "thesises_extraction_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           }
#      },
#      "updator": {
#           "replace_simple_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           },
#           "replace_hyper_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           }
#      }
# }

# %%
print("qa kv_cache info:")
print(json.dumps(personalai.qa_pipeline.get_cache_stat(), indent=5))
print("qa agent tgen info:")
print(json.dumps(personalai.qa_pipeline.get_agent_tgen_stat(), indent=5))
# Out:
# qa kv_cache info:
# {
#      "QAPipeline": 0,
#      "query_preprocessor": {
#           "QueryPreprocessor": 0,
#           "denoiser": null,
#           "enhancer": null,
#           "decomposer": null
#      },
#      "kg_reasoner": {
#           "KnowledgeGraphReasoner": 0,
#           "reasoner": {
#                "WeakKGReasoner": 0,
#                "knowledge_retriever": {
#                     "KnowledgeRetriever": 0,
#                     "triplets_retriever": {
#                          "WaterCirclesRetriever": {
#                               "WaterCirclesRetriever": 0,
#                               "traversal_cache": null
#                          }
#                     },
#                     "triplets_filter": {
#                          "TripletsFilter": 0
#                     }
#                },
#                "answer_generator": {
#                     "QALLMGenerator": 0,
#                     "answer_generator_solver": 0
#                },
#                "query_parser": {
#                     "QueryLLMParser": 0,
#                     "kw_extraction_solver": 0
#                },
#                "knowledge_comparator": {
#                     "KnowledgeComparator": 0
#                }
#           }
#      },
#      "answers_aggregator": {
#           "AnswersAggregator": 0,
#           "subanswers_summarisation_solver": 0
#      }
# }
# qa agent tgen info:
# {
#      "query_preprocessor": {},
#      "kg_reasoner": {
#           "reasoner": {
#                "answer_generator": {
#                     "answer_generator_solver": {
#                          "prompt_tokens_amount": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          },
#                          "generated_tokens_amount": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          },
#                          "inference_elapsed_time": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          }
#                     }
#                },
#                "query_parser": {
#                     "kw_extraction_solver": {
#                          "prompt_tokens_amount": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          },
#                          "generated_tokens_amount": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          },
#                          "inference_elapsed_time": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          }
#                     }
#                }
#           }
#      },
#      "answers_aggregator": {
#           "subanswers_summarisation_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           }
#      }
# }

# %%
personalai.kg_model.clear()

# %%
print(json.dumps(personalai.kg_model.count_items(detailed=True),indent=5))
# Out:
# {
#      "graph_info": {
#           "triplets": {
#                "simple": 0,
#                "hyper": 0,
#                "episodic": 0,
#                "time": 0
#           },
#           "nodes": {
#                "object": 0,
#                "hyper": 0,
#                "episodic": 0,
#                "time": 0
#           }
#      },
#      "embeddings_info": {
#           "nodes": {
#                "object": {
#                     "nodes_dense": 0,
#                     "nodes_sparse_bm25": 0
#                },
#                "hyper": {
#                     "nodes_dense": 0,
#                     "nodes_sparse_bm25": 0
#                },
#                "episodic": {
#                     "nodes_dense": 0,
#                     "nodes_sparse_bm25": 0
#                },
#                "time": {
#                     "nodes_dense": 0,
#                     "nodes_sparse_bm25": 0
#                }
#           },
#           "triplets": {
#                "triplets_dense": 0,
#                "triplets_sparse_bm25": 0
#           }
#      },
#      "nodestree_info": null
# }

# %%
TEXT_EXAMPLES = [
    "Проживающие в общежитии студенты имеют право rруглосуточного доступа к месту проживания.",
    "Проживающие в общежитии студенты имеют право обратиться к администрации ФГБУ «МСГ» с заявлением, заверенным заведующим общежития, о размещении в гостевых комнатах общежития родственников (на короткий период пребывания, не менее 2-х суток), родителей - на любой срок (при предоставлении документа, подтверждающего степень родства).",
    "Проживающие в общежитии студенты имеют право пользоваться помещениями для самостоятельных занятий и помещениями культурно-бытового назначения, оборудованием, инвентарем общежития.",
    "Проживающие в общежитии студенты имеют право обращаться к администрации корпуса с просьбами о своевременном ремонте, замене оборудования и инвентаря, вышедшего из строя не по их вине.",
    "Проживающие в общежитии студенты имеют право на переселение из одного помещения в другое в том же корпусе, а также на переселение из одного корпуса в другой при наличии свободных мест, с согласия администрации корпуса.",
    "Проживающие в общежитии студенты имеют право участвовать в формировании и выборах Студенческого совета МСГ и быть избранным в его состав.",
    "Проживающие в общежитии студенты имеют право участвовать (вносить предложения) через Студенческий совет МСГ и отдел по молодежной политике ФГБУ «МСГ» в решении вопросов совершенствования жилищно-бытовых условий, организации воспитательной работы и досуга.",
    "Проживающие в общежитии студенты имеют право принимать участие в общественных, спортивных и культурно-досуговых мероприятиях, организованных администрацией ФГБУ «МСГ» и Студенческим советом МСГ.",
    "Проживающие в общежитии студенты имеют право пользоваться разрешенной бытовой техникой с соблюдением правил техники безопасности и правил пожарной безопасности.",
    "Проживающие в общежитии студенты имеют право бесплатно посещать Межвузовский  учебно-спортивный центр в утвержденное администрацией ФГБУ «МСГ» и согласованное со Студенческим советом МСГ время.",
    "Проживающие в общежитии студенты имеют право бесплатно посещать душевой комплекс с сауной ФГБУ «МСГ» в отведенное администрацией ФГБУ «МСГ» время.",

    "Проживающие в общежитии студенты обязаны ознакомиться с настоящими Правилами.",
    "Проживающие в общежитии студенты обязаны cтрого соблюдать настоящие Правила, правила техники безопасности, правила пожарной безопасности, требования (рекомендации) Рсопотребнадзора.",
    "Проживающие в общежитии студенты обязаны принимать участие в проведении инструкторско-методических занятий по теме: «Организация эвакуации людей из студенческого общежития при возникновении пожара и чрезвычайных ситуациях».",
    "Проживающие в общежитии студенты обязаны при чрезвычайных ситуациях и срабатывании оповещения — покинуть общежитие.",
    "Проживающие в общежитии студенты обязаны выполнять условия договора найма жилого помещения.",
    "Проживающие в общежитии студенты обязаны В установленном порядке и сроки представлять документы для регистрации по месту пребывания, своевременно предоставлять в отдел учета, размещения и регистрации информацию о смене паспортных данных (20 лет — замена паспорта, смена фамилии и др. личные данные).",
    "Проживающие в общежитии студенты обязаны ежегодно представлять администрации корпуса копию справки о прохождении флюорографии (ФЛГ).",
    "Проживающие в общежитии студенты обязаны своевременно в соответствии с условиями договора найма жилого помещения в общежитии вносить плату в установленных размерах за проживание в общежитии и за все виды предоставляемых дополнительных платных услуг.",
    "Проживающие в общежитии студенты обязаны по требованию администрации корпуса предъявлять электронный пропуск установленного образца на право входа в общежитие.",

    "Проживающие в общежитии студенты обязаны обеспечить возможность осмотра жилой комнаты администрацией корпуса в присутствии членов Студенческого совета МСГ или проживающих на этаже студентов с целью контроля санитарного состояния, проверки сохранности имущества, проведения профилактических и других видов работ.",
    "Проживающие в общежитии студенты обязаны не допускать, а в случае обнаружения сообщать администрации корпуса и администрации ФГБУ «МСГ», любые попытки распространения информации или пропаганды сомнительных организаций (террористических), так как это противоречит действующему законодательству РФ.",
    "Проживающие в общежитии студенты обязаны принимать посетителей только в установленное администрацией ФГБУ «МСГ» время, согласно графику посещения гостей, утвержденному директором ФГБУ «МСГ». Время визитов для посторонних посетителей: среда с 17.00 до 21.00, суббота, воскресенье, праздничные дни с 13.00 до 21.00, время визитов для посетителей из ФГБУ «МСГ»: с понедельника по пятницу с 17.00 до 21.00, в субботу, воскресенье, праздничные дни с 13.00 до 21.00.",
    "Проживающие в общежитии студенты обязаны при временном отсутствии более чем на 3 суток (каникулы, практика, стажировка и др.) письменно уведомить администрацию корпуса не менее чем за 2 (два) дня до предполагаемого выбытия.",
    "Проживающие в общежитии студенты обязаныво время пользования помещениями для самостоятельных занятий и культурно-бытового назначения соблюдать тишину и не создавать препятствий другим проживающим в пользовании указанными помещениями.",
    "Проживающие в общежитии студенты обязаныбережно относиться к помещениям, оборудованию и инвентарю.",
    "Проживающие в общежитии студенты обязанынаходясь на кухне, проявлять повьшиенное внимание к работающим бытовым приборам (особенно к газовым плитам) во избежание задымления, возгорания (выключать кипящие чайники, кастрюли, подгорающую пищу и т.п.).",
    "Проживающие в общежитии студенты обязанына основании графика, установленного Старостой этажа, добросовестно нести обязанности по дежурству на кухне.",

    "Проживающие в общежитии студенты обязаныэкономно расходовать электроэнергию, газ и воду.",
    "Проживающие в общежитии студенты обязанысоблюдать чистоту и порядок в жилых помещениях и местах общего пользования, осуществлять влажную уборку жилого помещения не реже 3-х раз в неделю, в соответствии с графиком уборки комнаты.",
    "Проживающие в общежитии студенты обязаныв случае обнаружения неисправностей датчиков пожарной безопасности, электричества, отопительных батарей, инвентаря, оборудования и насекомых сообщить администрации корпуса либо заполнить форму заявки в системе АСУ «Заявки» по адресу: ВИр://арр.т1зе-зрь.га.",
    "Проживающие в общежитии студенты обязаны возмещать причиненный материальный ущерб в соответствии с действующим законодательством и договором найма жилого помещения.",
    "Проживающие в общежитии студенты обязаны соблюдать требования морально-этических норм поведения, поддерживать атмосферу доброжелательности и взаимного уважения по отношению к проживающим, работникам, администрации корпуса, администрации ФГБУ «МСГ» и членам Студенческого совета МСГ."
]

# %%
extracted_triplets = []
for i, example in enumerate(TEXT_EXAMPLES):
    print(f"{i+1}. {example}")
    tmp_extracted_triplets, _ = personalai.update_memory(example)
    extracted_triplets += tmp_extracted_triplets
    print("extracted triplets: ", len(tmp_extracted_triplets))
# Out:
# 1. Проживающие в общежитии студенты имеют право rруглосуточного доступа к месту проживания.
# extracted triplets:  11
# 2. Проживающие в общежитии студенты имеют право обратиться к администрации ФГБУ «МСГ» с заявлением, заверенным заведующим общежития, о размещении в гостевых комнатах общежития родственников (на короткий период пребывания, не менее 2-х суток), родителей - на любой срок (при предоставлении документа, подтверждающего степень родства).
# extracted triplets:  45
# 3. Проживающие в общежитии студенты имеют право пользоваться помещениями для самостоятельных занятий и помещениями культурно-бытового назначения, оборудованием, инвентарем общежития.
# extracted triplets:  35
# 4. Проживающие в общежитии студенты имеют право обращаться к администрации корпуса с просьбами о своевременном ремонте, замене оборудования и инвентаря, вышедшего из строя не по их вине.
# extracted triplets:  24
# 5. Проживающие в общежитии студенты имеют право на переселение из одного помещения в другое в том же корпусе, а также на переселение из одного корпуса в другой при наличии свободных мест, с согласия администрации корпуса.
# extracted triplets:  26
# 6. Проживающие в общежитии студенты имеют право участвовать в формировании и выборах Студенческого совета МСГ и быть избранным в его состав.
# extracted triplets:  22
# 7. Проживающие в общежитии студенты имеют право участвовать (вносить предложения) через Студенческий совет МСГ и отдел по молодежной политике ФГБУ «МСГ» в решении вопросов совершенствования жилищно-бытовых условий, организации воспитательной работы и досуга.
# extracted triplets:  52
# 8. Проживающие в общежитии студенты имеют право принимать участие в общественных, спортивных и культурно-досуговых мероприятиях, организованных администрацией ФГБУ «МСГ» и Студенческим советом МСГ.
# extracted triplets:  34
# 9. Проживающие в общежитии студенты имеют право пользоваться разрешенной бытовой техникой с соблюдением правил техники безопасности и правил пожарной безопасности.
# extracted triplets:  26
# 10. Проживающие в общежитии студенты имеют право бесплатно посещать Межвузовский  учебно-спортивный центр в утвержденное администрацией ФГБУ «МСГ» и согласованное со Студенческим советом МСГ время.
# extracted triplets:  31
# 11. Проживающие в общежитии студенты имеют право бесплатно посещать душевой комплекс с сауной ФГБУ «МСГ» в отведенное администрацией ФГБУ «МСГ» время.
# extracted triplets:  29
# 12. Проживающие в общежитии студенты обязаны ознакомиться с настоящими Правилами.
# extracted triplets:  12
# 13. Проживающие в общежитии студенты обязаны cтрого соблюдать настоящие Правила, правила техники безопасности, правила пожарной безопасности, требования (рекомендации) Рсопотребнадзора.
# extracted triplets:  30
# 14. Проживающие в общежитии студенты обязаны принимать участие в проведении инструкторско-методических занятий по теме: «Организация эвакуации людей из студенческого общежития при возникновении пожара и чрезвычайных ситуациях».
# extracted triplets:  32
# 15. Проживающие в общежитии студенты обязаны при чрезвычайных ситуациях и срабатывании оповещения — покинуть общежитие.
# extracted triplets:  17
# 16. Проживающие в общежитии студенты обязаны выполнять условия договора найма жилого помещения.
# extracted triplets:  17
# 17. Проживающие в общежитии студенты обязаны В установленном порядке и сроки представлять документы для регистрации по месту пребывания, своевременно предоставлять в отдел учета, размещения и регистрации информацию о смене паспортных данных (20 лет — замена паспорта, смена фамилии и др. личные данные).
# extracted triplets:  30
# 18. Проживающие в общежитии студенты обязаны ежегодно представлять администрации корпуса копию справки о прохождении флюорографии (ФЛГ).
# extracted triplets:  21
# 19. Проживающие в общежитии студенты обязаны своевременно в соответствии с условиями договора найма жилого помещения в общежитии вносить плату в установленных размерах за проживание в общежитии и за все виды предоставляемых дополнительных платных услуг.
# extracted triplets:  31
# 20. Проживающие в общежитии студенты обязаны по требованию администрации корпуса предъявлять электронный пропуск установленного образца на право входа в общежитие.
# extracted triplets:  26
# 21. Проживающие в общежитии студенты обязаны обеспечить возможность осмотра жилой комнаты администрацией корпуса в присутствии членов Студенческого совета МСГ или проживающих на этаже студентов с целью контроля санитарного состояния, проверки сохранности имущества, проведения профилактических и других видов работ.
# extracted triplets:  47
# 22. Проживающие в общежитии студенты обязаны не допускать, а в случае обнаружения сообщать администрации корпуса и администрации ФГБУ «МСГ», любые попытки распространения информации или пропаганды сомнительных организаций (террористических), так как это противоречит действующему законодательству РФ.
# extracted triplets:  34
# 23. Проживающие в общежитии студенты обязаны принимать посетителей только в установленное администрацией ФГБУ «МСГ» время, согласно графику посещения гостей, утвержденному директором ФГБУ «МСГ». Время визитов для посторонних посетителей: среда с 17.00 до 21.00, суббота, воскресенье, праздничные дни с 13.00 до 21.00, время визитов для посетителей из ФГБУ «МСГ»: с понедельника по пятницу с 17.00 до 21.00, в субботу, воскресенье, праздничные дни с 13.00 до 21.00.
# extracted triplets:  77
# 24. Проживающие в общежитии студенты обязаны при временном отсутствии более чем на 3 суток (каникулы, практика, стажировка и др.) письменно уведомить администрацию корпуса не менее чем за 2 (два) дня до предполагаемого выбытия.
# extracted triplets:  13
# 25. Проживающие в общежитии студенты обязаныво время пользования помещениями для самостоятельных занятий и культурно-бытового назначения соблюдать тишину и не создавать препятствий другим проживающим в пользовании указанными помещениями.
# extracted triplets:  35
# 26. Проживающие в общежитии студенты обязаныбережно относиться к помещениям, оборудованию и инвентарю.
# extracted triplets:  26
# 27. Проживающие в общежитии студенты обязанынаходясь на кухне, проявлять повьшиенное внимание к работающим бытовым приборам (особенно к газовым плитам) во избежание задымления, возгорания (выключать кипящие чайники, кастрюли, подгорающую пищу и т.п.).
# extracted triplets:  49
# 28. Проживающие в общежитии студенты обязанына основании графика, установленного Старостой этажа, добросовестно нести обязанности по дежурству на кухне.
# extracted triplets:  28
# 29. Проживающие в общежитии студенты обязаныэкономно расходовать электроэнергию, газ и воду.
# extracted triplets:  30
# 30. Проживающие в общежитии студенты обязанысоблюдать чистоту и порядок в жилых помещениях и местах общего пользования, осуществлять влажную уборку жилого помещения не реже 3-х раз в неделю, в соответствии с графиком уборки комнаты.
# extracted triplets:  13
# 31. Проживающие в общежитии студенты обязаныв случае обнаружения неисправностей датчиков пожарной безопасности, электричества, отопительных батарей, инвентаря, оборудования и насекомых сообщить администрации корпуса либо заполнить форму заявки в системе АСУ «Заявки» по адресу: ВИр://арр.т1зе-зрь.га.
# extracted triplets:  21
# 32. Проживающие в общежитии студенты обязаны возмещать причиненный материальный ущерб в соответствии с действующим законодательством и договором найма жилого помещения.
# extracted triplets:  27
# 33. Проживающие в общежитии студенты обязаны соблюдать требования морально-этических норм поведения, поддерживать атмосферу доброжелательности и взаимного уважения по отношению к проживающим, работникам, администрации корпуса, администрации ФГБУ «МСГ» и членам Студенческого совета МСГ.
# extracted triplets:  43

# %%
print(json.dumps(personalai.kg_model.count_items(detailed=True),indent=5))
personalai.kg_model.check_consistency()
# Out:
# {
#      "graph_info": {
#           "triplets": {
#                "simple": 123,
#                "hyper": 348,
#                "episodic": 490,
#                "time": 0
#           },
#           "nodes": {
#                "object": 242,
#                "hyper": 112,
#                "episodic": 33,
#                "time": 0
#           }
#      },
#      "embeddings_info": {
#           "nodes": {
#                "object": {
#                     "nodes_dense": 242,
#                     "nodes_sparse_bm25": 242
#                },
#                "hyper": {
#                     "nodes_dense": 112,
#                     "nodes_sparse_bm25": 112
#                },
#                "episodic": {
#                     "nodes_dense": 33,
#                     "nodes_sparse_bm25": 33
#                },
#                "time": {
#                     "nodes_dense": 0,
#                     "nodes_sparse_bm25": 0
#                }
#           },
#           "triplets": {
#                "triplets_dense": 262,
#                "triplets_sparse_bm25": 262
#           }
#      },
#      "nodestree_info": null
# }
# True

# %%
print("mem kv_cache info:")
print(json.dumps(personalai.mem_pipeline.get_cache_stat(), indent=5))
print("mem agent tgen info:")
print(json.dumps(personalai.mem_pipeline.get_agent_tgen_stat(), indent=5))
# Out:
# mem kv_cache info:
# {
#      "MemPipeline": null,
#      "extractor": {
#           "LLMExtractor": null,
#           "triplets_extraction_solver": 33,
#           "thesises_extraction_solver": 33
#      },
#      "updator": {
#           "LLMUpdator": null,
#           "replace_simple_solver": 0,
#           "replace_hyper_solver": 0
#      }
# }
# mem agent tgen info:
# {
#      "extractor": {
#           "triplets_extraction_solver": {
#                "prompt_tokens_amount": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 846,
#                     "max": 996,
#                     "median": 877,
#                     "mean": 882.485,
#                     "std": 28.824,
#                     "sum": 29122
#                },
#                "generated_tokens_amount": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 20,
#                     "max": 422,
#                     "median": 66,
#                     "mean": 87.576,
#                     "std": 69.533,
#                     "sum": 2890
#                },
#                "inference_elapsed_time": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 1.91,
#                     "max": 17.46,
#                     "median": 3.71,
#                     "mean": 4.598,
#                     "std": 2.765,
#                     "sum": 151.72
#                }
#           },
#           "thesises_extraction_solver": {
#                "prompt_tokens_amount": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 876,
#                     "max": 1026,
#                     "median": 907,
#                     "mean": 912.485,
#                     "std": 28.824,
#                     "sum": 30112
#                },
#                "generated_tokens_amount": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 41,
#                     "max": 686,
#                     "median": 141,
#                     "mean": 179.576,
#                     "std": 125.055,
#                     "sum": 5926
#                },
#                "inference_elapsed_time": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 2.77,
#                     "max": 27.91,
#                     "median": 7.3,
#                     "mean": 8.44,
#                     "std": 5.351,
#                     "sum": 278.53
#                }
#           }
#      },
#      "updator": {
#           "replace_simple_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           },
#           "replace_hyper_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           }
#      }
# }

# %%
answer1, rinfo = personalai.answer_question("Какими помещениями разрешено пользоваться студентам, проживающим в общещитии МСГ?")
pprint(answer1)
# Out:
# 'Душевой комплекс с сауной и гостевые комнаты общежития.'

# %%
answer2, rinfo = personalai.answer_question("Разрешено ли студентам, проживающим в общежитии МСГ пользоваться бытовой техникой?")
pprint(answer2)
# Out:
# '<|NotEnoughtInfo|>'

# %%
answer3, rinfo = personalai.answer_question("Могут ли проживающие в общежитии МСГ обращаться к администрации с вопросами?")
pprint(answer3)
# Out:
# '<|NotEnoughtInfo|>'

# %%
print("qa kv_cache info:")
print(json.dumps(personalai.qa_pipeline.get_cache_stat(), indent=5))
print("qa agent tgen info:")
print(json.dumps(personalai.qa_pipeline.get_agent_tgen_stat(), indent=5))
# Out:
# qa kv_cache info:
# {
#      "QAPipeline": 3,
#      "query_preprocessor": {
#           "QueryPreprocessor": 3,
#           "denoiser": null,
#           "enhancer": null,
#           "decomposer": null
#      },
#      "kg_reasoner": {
#           "KnowledgeGraphReasoner": 3,
#           "reasoner": {
#                "WeakKGReasoner": 3,
#                "knowledge_retriever": {
#                     "KnowledgeRetriever": 3,
#                     "triplets_retriever": {
#                          "WaterCirclesRetriever": {
#                               "WaterCirclesRetriever": 3,
#                               "traversal_cache": null
#                          }
#                     },
#                     "triplets_filter": {
#                          "TripletsFilter": 3
#                     }
#                },
#                "answer_generator": {
#                     "QALLMGenerator": 3,
#                     "answer_generator_solver": 3
#                },
#                "query_parser": {
#                     "QueryLLMParser": 3,
#                     "kw_extraction_solver": 3
#                },
#                "knowledge_comparator": {
#                     "KnowledgeComparator": 3
#                }
#           }
#      },
#      "answers_aggregator": {
#           "AnswersAggregator": 3,
#           "subanswers_summarisation_solver": 0
#      }
# }
# qa agent tgen info:
# {
#      "query_preprocessor": {},
#      "kg_reasoner": {
#           "reasoner": {
#                "answer_generator": {
#                     "answer_generator_solver": {
#                          "prompt_tokens_amount": {
#                               "count": 3,
#                               "count_not_null": 3,
#                               "min": 1886,
#                               "max": 1919,
#                               "median": 1914,
#                               "mean": 1906.333,
#                               "std": 14.522,
#                               "sum": 5719
#                          },
#                          "generated_tokens_amount": {
#                               "count": 3,
#                               "count_not_null": 3,
#                               "min": 69,
#                               "max": 152,
#                               "median": 123,
#                               "mean": 114.667,
#                               "std": 34.393,
#                               "sum": 344
#                          },
#                          "inference_elapsed_time": {
#                               "count": 3,
#                               "count_not_null": 3,
#                               "min": 5.01,
#                               "max": 8.19,
#                               "median": 7.05,
#                               "mean": 6.75,
#                               "std": 1.315,
#                               "sum": 20.25
#                          }
#                     }
#                },
#                "query_parser": {
#                     "kw_extraction_solver": {
#                          "prompt_tokens_amount": {
#                               "count": 3,
#                               "count_not_null": 3,
#                               "min": 483,
#                               "max": 488,
#                               "median": 484,
#                               "mean": 485.0,
#                               "std": 2.16,
#                               "sum": 1455
#                          },
#                          "generated_tokens_amount": {
#                               "count": 3,
#                               "count_not_null": 3,
#                               "min": 12,
#                               "max": 19,
#                               "median": 15,
#                               "mean": 15.333,
#                               "std": 2.867,
#                               "sum": 46
#                          },
#                          "inference_elapsed_time": {
#                               "count": 3,
#                               "count_not_null": 3,
#                               "min": 1.06,
#                               "max": 1.55,
#                               "median": 1.37,
#                               "mean": 1.327,
#                               "std": 0.202,
#                               "sum": 3.98
#                          }
#                     }
#                }
#           }
#      },
#      "answers_aggregator": {
#           "subanswers_summarisation_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           }
#      }
# }

# %%
personalai.kg_model.count_items()
# Out:
# {'graph_info': {'triplets': 961, 'nodes': 387},
#  'embeddings_info': {'nodes': 387, 'triplets': 262},
#  'nodestree_info': None}

# %%
#personalai.mem_pipeline.clear_kv_caches()
#personalai.mem_pipeline.clear_agent_tgen_stat()
personalai.qa_pipeline.clear_kv_caches()
personalai.qa_pipeline.clear_agent_tgen_stat()

# %%
print("mem kv_cache info:")
print(json.dumps(personalai.mem_pipeline.get_cache_stat(), indent=5))
print("mem agent tgen info:")
print(json.dumps(personalai.mem_pipeline.get_agent_tgen_stat(), indent=5))
print("qa kv_cache info:")
print(json.dumps(personalai.qa_pipeline.get_cache_stat(), indent=5))
print("qa agent tgen info:")
print(json.dumps(personalai.qa_pipeline.get_agent_tgen_stat(), indent=5))
# Out:
# mem kv_cache info:
# {
#      "MemPipeline": null,
#      "extractor": {
#           "LLMExtractor": null,
#           "triplets_extraction_solver": 33,
#           "thesises_extraction_solver": 33
#      },
#      "updator": {
#           "LLMUpdator": null,
#           "replace_simple_solver": 0,
#           "replace_hyper_solver": 0
#      }
# }
# mem agent tgen info:
# {
#      "extractor": {
#           "triplets_extraction_solver": {
#                "prompt_tokens_amount": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 846,
#                     "max": 996,
#                     "median": 877,
#                     "mean": 882.485,
#                     "std": 28.824,
#                     "sum": 29122
#                },
#                "generated_tokens_amount": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 20,
#                     "max": 422,
#                     "median": 66,
#                     "mean": 87.576,
#                     "std": 69.533,
#                     "sum": 2890
#                },
#                "inference_elapsed_time": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 1.91,
#                     "max": 17.46,
#                     "median": 3.71,
#                     "mean": 4.598,
#                     "std": 2.765,
#                     "sum": 151.72
#                }
#           },
#           "thesises_extraction_solver": {
#                "prompt_tokens_amount": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 876,
#                     "max": 1026,
#                     "median": 907,
#                     "mean": 912.485,
#                     "std": 28.824,
#                     "sum": 30112
#                },
#                "generated_tokens_amount": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 41,
#                     "max": 686,
#                     "median": 141,
#                     "mean": 179.576,
#                     "std": 125.055,
#                     "sum": 5926
#                },
#                "inference_elapsed_time": {
#                     "count": 33,
#                     "count_not_null": 33,
#                     "min": 2.77,
#                     "max": 27.91,
#                     "median": 7.3,
#                     "mean": 8.44,
#                     "std": 5.351,
#                     "sum": 278.53
#                }
#           }
#      },
#      "updator": {
#           "replace_simple_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           },
#           "replace_hyper_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           }
#      }
# }
# qa kv_cache info:
# {
#      "QAPipeline": 0,
#      "query_preprocessor": {
#           "QueryPreprocessor": 0,
#           "denoiser": null,
#           "enhancer": null,
#           "decomposer": null
#      },
#      "kg_reasoner": {
#           "KnowledgeGraphReasoner": 0,
#           "reasoner": {
#                "WeakKGReasoner": 0,
#                "knowledge_retriever": {
#                     "KnowledgeRetriever": 0,
#                     "triplets_retriever": {
#                          "WaterCirclesRetriever": {
#                               "WaterCirclesRetriever": 3,
#                               "traversal_cache": null
#                          }
#                     },
#                     "triplets_filter": {
#                          "TripletsFilter": 0
#                     }
#                },
#                "answer_generator": {
#                     "QALLMGenerator": 0,
#                     "answer_generator_solver": 0
#                },
#                "query_parser": {
#                     "QueryLLMParser": 0,
#                     "kw_extraction_solver": 0
#                },
#                "knowledge_comparator": {
#                     "KnowledgeComparator": 0
#                }
#           }
#      },
#      "answers_aggregator": {
#           "AnswersAggregator": 0,
#           "subanswers_summarisation_solver": 0
#      }
# }
# qa agent tgen info:
# {
#      "query_preprocessor": {},
#      "kg_reasoner": {
#           "reasoner": {
#                "answer_generator": {
#                     "answer_generator_solver": {
#                          "prompt_tokens_amount": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          },
#                          "generated_tokens_amount": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          },
#                          "inference_elapsed_time": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          }
#                     }
#                },
#                "query_parser": {
#                     "kw_extraction_solver": {
#                          "prompt_tokens_amount": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          },
#                          "generated_tokens_amount": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          },
#                          "inference_elapsed_time": {
#                               "count": 0,
#                               "count_not_null": 0,
#                               "min": null,
#                               "max": null,
#                               "median": null,
#                               "mean": null,
#                               "std": null,
#                               "sum": null
#                          }
#                     }
#                }
#           }
#      },
#      "answers_aggregator": {
#           "subanswers_summarisation_solver": {
#                "prompt_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "generated_tokens_amount": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                },
#                "inference_elapsed_time": {
#                     "count": 0,
#                     "count_not_null": 0,
#                     "min": null,
#                     "max": null,
#                     "median": null,
#                     "mean": null,
#                     "std": null,
#                     "sum": null
#                }
#           }
#      }
# }

# %%
del personalai
# Out:
# /home/dzigen/Desktop/Projects/PersonalAI/Personal-AI/docs/notebooks/../../src/agents/connectors/OLlamaConnector.py:43: ResourceWarning: unclosed <socket.socket fd=134, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('127.0.0.1', 34752), raddr=('127.0.0.1', 11437)>
#   del self.client
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
