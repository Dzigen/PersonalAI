# %%
import sys

# TO CHANGE
BASEDIR = "/home/dzigen/Desktop/PersonalAI/Personal-AI"
# TO CHNAGE

sys.path.insert(0, BASEDIR)

import chromadb

# %%
vector_conn = chromadb.PersistentClient(path='tesing_db').create_collection("example")

# %%
vector_conn.add(ids=['123'], embeddings=[[1,2,3,4]], documents=['helloworld'])

# %%
vector_conn.get(ids=['123'])
# Out:
# {'ids': ['123'],
#  'embeddings': None,
#  'metadatas': [None],
#  'documents': ['helloworld'],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents']}

# %%
vector_conn.add(ids=['123'], embeddings=[[1,2,3,4]], documents=['helloworld_20'])
# Out:
# Insert of existing embedding ID: 123
# Add of existing embedding ID: 123

# %%
vector_conn.get(ids=['123'])
# Out:
# {'ids': ['123'],
#  'embeddings': None,
#  'metadatas': [None],
#  'documents': ['helloworld'],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents']}

# %%
vector_conn.add(ids=['1234'], embeddings=[[1,2,3,4]], documents=['helloworld_20'])

# %%
vector_conn.get(ids=['1234'])
# Out:
# {'ids': ['1234'],
#  'embeddings': None,
#  'metadatas': [None],
#  'documents': ['helloworld_20'],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents']}

# %%
vector_conn.count()
# Out:
# 2
