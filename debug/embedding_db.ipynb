# %%
import chromadb

# %%
import sys
BASEDIR = "/home/dzigen/Desktop/PersonalAI/Personal-AI"
sys.path.insert(0, BASEDIR)

from src.embedding_functions import EmbedderModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       2 BASEDIR = "/home/dzigen/Desktop/PersonalAI/Personal-AI"
#       3 sys.path.insert(0, BASEDIR)
# ----> 5 from src.embedding_functions import EmbedderModel
#
# File ~/Desktop/PersonalAI/Personal-AI/src/__init__.py:2
#       1 from .utils import *
# ----> 2 from embedding_functions import *
#
# ModuleNotFoundError: No module named 'embedding_functions'

# %%
MODEL_KWARGS = {'device': 'cuda'}
ENCODE_PROMPTS = {"query": "query: ", "passage": "passage: "}
ENCODE_KWARGS = {'normalize_embeddings': True, 'prompt': ENCODE_PROMPTS['passage']}
CHROMA_KWARGS = {"hnsw:space": "ip"}

# %%
client = chromadb.PersistentClient(path=NODES_DB_PATH)
NODES_COLLECTION = client.get_collection(name=NODES_DB_META["data_name"])

EMBEDDER = HuggingFaceEmbeddings(
    model_name=NODES_DB_META["model_name"],
    model_kwargs={'device': 'cuda'},
    encode_kwargs=NODES_DB_META["encode_kwargs"]
    )
