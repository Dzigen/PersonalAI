# %%
import sys

# TO CHANGE
BASEDIR = "/home/dzigen/Desktop/PersonalAI/Personal-AI"
# TO CHNAGE

sys.path.insert(0, BASEDIR)

# %%
from src.neo4j_functions import Neo4jConnection

# %%
graph_db = Neo4jConnection(uri="bolt://31.207.47.254:7687", user="neo4j", pwd="password")

# %%
test_triplet = [{'name': "test_start_node_name", "type": "entity", "prop": {}},
                {"type": "simple", "prop": {}},
                {'name': "test_end_node_name", "type": "entity", "prop": {}}]

# %%
# ids for added triplets
output = graph_db.create_triplets([test_triplet], db='testdb')
# Out:
# Query failed: {code: Neo.ClientError.Statement.SyntaxError} {message: Variable `test_start_node_name` not defined (line 1, column 39 (offset: 38))
# "MATCH (subj:entity) WHERE subj.name = test_start_node_name RETURN elementID(subj) as id"
#                                        ^}
# Query failed: {code: Neo.ClientError.Statement.SyntaxError} {message: Variable `test_end_node_name` not defined (line 1, column 39 (offset: 38))
# "MATCH (subj:entity) WHERE subj.name = test_end_node_name RETURN elementID(obj) as id"
#                                        ^}

# %%
output
# Out:
# [('4:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:1441',
#   '5:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:10356',
#   '4:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:1442')]

# %%
# triplet, associated with following ids
cur_triplet_ids = output[0]

output2 = graph_db.execute_query(
    f'MATCH (a)-[rel]-(b) WHERE elementId(a) = "{cur_triplet_ids[0]}" AND elementID(rel) = "{cur_triplet_ids[1]}" AND elementId(b) = "{cur_triplet_ids[2]}" RETURN a, rel, b', db='testdb')

# %%
output2
# Out:
# [<Record a=<Node element_id='4:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:1441' labels=frozenset({'entity'}) properties={'name': 'test_start_node_name'}> rel=<Relationship element_id='5:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:10356' nodes=(<Node element_id='4:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:1441' labels=frozenset({'entity'}) properties={'name': 'test_start_node_name'}>, <Node element_id='4:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:1442' labels=frozenset({'entity'}) properties={'name': 'test_end_node_name'}>) type='simple' properties={}> b=<Node element_id='4:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:1442' labels=frozenset({'entity'}) properties={'name': 'test_end_node_name'}>>]

# %%
# delete added triplet
cur_triplet_ids = output[0]

output3 = graph_db.execute_query(
    f'MATCH (a)-[rel]-(b) WHERE elementId(a) = "{cur_triplet_ids[0]}" AND elementID(rel) = "{cur_triplet_ids[1]}" AND elementId(b) = "{cur_triplet_ids[2]}" DELETE a, rel, b', db='testdb')

# %%
# check, if deleted triplet exist in graph-db
cur_triplet_ids = output[0]

output4 = graph_db.execute_query(
    f'MATCH (a)-[rel]-(b) WHERE elementId(a) = "{cur_triplet_ids[0]}" AND elementID(rel) = "{cur_triplet_ids[1]}" AND elementId(b) = "{cur_triplet_ids[2]}" RETURN a, rel, b', db='testdb')

# %%
output4
# Out:
# []
