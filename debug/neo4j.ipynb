# %%
from neo4j import GraphDatabase

# %%
driver = GraphDatabase.driver("bolt://31.207.47.254:7687", auth=("neo4j", "password"))

# %%
CREATE (a {name:'john doe'}) RETURN a

# %%
session = driver.session(database='testdb')

# %%
response = list(session.run("CREATE (a {name:'test john doe'}) RETURN elementId(a) as id"))

# %%
response[0]['id']
# Out:
# '4:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:1437'

# %%
resp2 = list(session.run('MATCH (node) WHERE  elementId(node) = "4:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:1437" DETACH DELETE node'))

# %%
resp3 = list(session.run('MATCH (node) WHERE elementId(node) = "4:c6e7bf7b-2028-48c7-a07a-45dfd8bdb964:1437" RETURN node'))

# %%
resp3
# Out:
# []
